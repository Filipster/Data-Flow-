# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns
# %matplotlib inline


df = pd.read_csv("convertcsv.csv")

# %%
df.head(30)
# Out:
#     ID        Country         Admin_region               Town  Latitude  \
# 0    1        Nigeria         Kaduna State             Rahama   10.4134
# 1    2        Liberia          Lofa County             Zorzor    7.7700
# 2    3        Nigeria          Borno State              Lassa   10.6900
# 3    4        Nigeria        Plateau State                Jos    9.9200
# 4    5  Cote d'Ivoire    Beoumi Prefecture             Beoumi    7.6700
# 5    6        Nigeria  Benue Plateau State              Bassa    9.9300
# 6    7        Nigeria        Plateau State                Jos    9.9200
# 7    8        Nigeria        Not specified                Jos    9.9365
# 8    9   Sierra Leone    Kailahun District              Mobai    7.9900
# 9   10   Sierra Leone      Kenema District    Tongo + Panguma    8.2200
# 10  11   Sierra Leone      Kenema District            Panguma    8.1800
# 11  12   Sierra Leone      Kenema District            Panguma    8.1900
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307 entries, 0 to 306
# Data columns (total 11 columns):
# ID                                307 non-null int64
# Country                           307 non-null object
# Admin_region                      307 non-null object
# Town                              307 non-null object
# Latitude                          307 non-null float64
# Longitude                         307 non-null float64
# Year_start                        307 non-null int64
# Year_end                          307 non-null int64
# Rodent_or_human                   307 non-null object
# Acutedisease_or_seroprevalence    307 non-null object
# Number_acutecases                 307 non-null object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 26.5+ KB

# %%
df['Country'].unique()
# Out:
# array(['Nigeria', 'Liberia', "Cote d'Ivoire", 'Sierra Leone', 'Mali',
#        'Burkina Faso', 'Guinea', 'Ghana', 'Benin'], dtype=object)

# %%
df['Acutedisease_or_seroprevalence'].unique()
# Out:
# array(['Acute', 'Seroprevalence'], dtype=object)

# %%
df_Acute = df[df['Acutedisease_or_seroprevalence']=='Acute']

# %%
df_Acute.head()
# Out:
#    ID        Country       Admin_region    Town  Latitude  Longitude  \
# 0   1        Nigeria       Kaduna State  Rahama   10.4134     8.6904
# 1   2        Liberia        Lofa County  Zorzor    7.7700    -9.4200
# 2   3        Nigeria        Borno State   Lassa   10.6900    13.3100
# 3   4        Nigeria      Plateau State     Jos    9.9200     8.9000
# 4   5  Cote d'Ivoire  Beoumi Prefecture  Beoumi    7.6700    -5.5700
#
#    Year_start  Year_end Rodent_or_human Acutedisease_or_seroprevalence  \
# 0        1952      1952           Human                          Acute
# 1        1969      1982           Human                          Acute
# 2        1969      1969           Human                          Acute
# 3        1969      1969           Human                          Acute
# 4        1970      1974           Human                          Acute
#
#   Number_acutecases
# 0                 1
# 1                38
# 2                 1
# 3                 2
# ...

# %%
df_Acute.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96 entries, 0 to 95
# Data columns (total 11 columns):
# ID                                96 non-null int64
# Country                           96 non-null object
# Admin_region                      96 non-null object
# Town                              96 non-null object
# Latitude                          96 non-null float64
# Longitude                         96 non-null float64
# Year_start                        96 non-null int64
# Year_end                          96 non-null int64
# Rodent_or_human                   96 non-null object
# Acutedisease_or_seroprevalence    96 non-null object
# Number_acutecases                 96 non-null object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 9.0+ KB

# %%
df_seroprevalence = df[df['Acutedisease_or_seroprevalence']=='seroprevalence']

# %%
df_seroprevalence.head()
# Out:
# Empty DataFrame
# Columns: [ID, Country, Admin_region, Town, Latitude, Longitude, Year_start, Year_end, Rodent_or_human, Acutedisease_or_seroprevalence, Number_acutecases]
# Index: []

# %%
df['Acutedisease_or_seroprevalence']=='seroprevalence'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 302    False
# 303    False
# 304    False
# 305    False
# 306    False
# Name: Acutedisease_or_seroprevalence, Length: 307, dtype: bool

# %%
df_Acute['Country'].value_counts()
# Out:
# Sierra Leone     33
# Nigeria          29
# Guinea           13
# Liberia          12
# Ghana             4
# Mali              2
# Burkina Faso      1
# Benin             1
# Cote d'Ivoire     1
# Name: Country, dtype: int64

# %%
df_Sierra_Leone = df_Acute[df_Acute['Country']=='Sierra Leone']

# %%
df_Sierra_Leone.drop(['ID', 'Rodent_or_human', 'Acutedisease_or_seroprevalence'], axis=1, inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_Sierra_Leone['Acute_cases'] = df_Sierra_Leone['Number_acutecases'].astype(int)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_Sierra_Leone.drop(['Number_acutecases'], axis=1, inplace=True)

# %%
df_Sierra_Leone.reset_index(inplace=True)

# %%
df_Sierra_Leone.drop('index', axis=1, inplace=True)

# %% [markdown]
# # Sierra Leone

# %% [markdown]
# df_Sierra_Leone

# %%
plt.figure(figsize=(15,6))
plt.ylabel('Count')
plt.xlabel('Administrated Region')
sns.set_style('white')
plt.title('Relation Between Administrated Regions in Sierra Leone and Number of Acutecases of Lassa Fever')
sns.countplot(x='Admin_region', data=df_Sierra_Leone)
plt.savefig('serraleonecountcerto1.png')

# %%
plt.figure(figsize=(12,8))
plt.ylabel('Year of end')
plt.xlabel('Year of Start')
sns.lineplot(x=df_Sierra_Leone['Year_start'],
            y=df_Sierra_Leone['Year_end'])
sns.line

# %%
plt.figure(figsize=(12,8))
sns.kdeplot(df_Sierra_Leone['Acute_cases'])
sns.rugplot(df_Sierra_Leone['Acute_cases'])

# %%
sns.set_context("paper")
plt.figure(figsize=(12,8))
sns.boxplot(x='Country', y='Acute_cases', data=df_Sierra_Leone)

# %%
plt.figure(figsize=(12,8))
sns.distplot(df_Sierra_Leone['Acute_cases'], bins=50)
plt.savefig('estesavefig.png')

# %%
plt.figure(figsize=(12,8))
sns.jointplot(x='Year_start', y='Acute_cases', data=df_Sierra_Leone, kind='hex')

# %%
plt.figure(figsize=(12,8))
sns.stripplot(x='Year_start', y='Acute_cases', data=df_Sierra_Leone, jitter=True)

# %%
plt.figure(figsize=(12,8))
sns.jointplot(x='Year_start', y='Year_end', data=df_Sierra_Leone, kind='hex')
plt.savefig('fig3plot.png')

# %%
plt.figure(figsize=(12,8))
sns.swarmplot(x='Year_start', y='Acute_cases', data=df_Sierra_Leone, color='black')
sns.violinplot(x='Year_start', y='Acute_cases', data=df_Sierra_Leone,)
plt.savefig('violinplotserra.png')

# %%
df1 = pd.DataFrame(df_Sierra_Leone.groupby('Admin_region').sum()['Acute_cases'])

df1.reset_index(inplace=True)

df1
# Out:
#         Admin_region  Acute_cases
# 0        Bo District           82
# 1  Kailahun District          207
# 2    Kenema District          643
# 3      Kono District            1
# 4   Moyamba District            6
# 5   Pujehun District            3
# 6          Tonkolili            6
# 7  Wester Area Rural           36

# %%
plt.figure(figsize=(25,10))
sns.barplot(x=df1['Admin_region'], y=df1['Acute_cases'], data=df1, palette="deep")

# %%
df2 = pd.DataFrame(df_Sierra_Leone.groupby('Year_start').sum()['Acute_cases'])

df2.reset_index(inplace=True)

df2
# Out:
#    Year_start  Acute_cases
# 0        1970          116
# 1        1975           11
# 2        1996          455
# 3        2000            1
# 4        2001          268
# 5        2003           90
# 6        2010            6
# 7        2014           36
# 8        2016            1

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x=df2['Year_start'], y=df2['Acute_cases'])

# %%
plt.figure(figsize=(12,8))
sns.jointplot(x='Year_start', y='Acute_cases', data=df2, color="k").plot_joint(sns.kdeplot, zorder=0, n_levels=6)

# %%
plt.figure(figsize=(12,8))
sns.jointplot(x='Year_start', y='Acute_cases', data=df2, kind='reg')

# %%
df3 = pd.DataFrame(df_Sierra_Leone.groupby('Year_end').sum()['Acute_cases'])

df3.reset_index(inplace=True)

df3
# Out:
#     Year_end  Acute_cases
# 0       1972           64
# 1       1975           52
# 2       1983           11
# 3       1997          455
# 4       2000            1
# 5       2001          268
# 6       2003           90
# 7       2004            0
# 8       2010            6
# 9       2015           36
# 10      2016            1

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x=df3['Year_end'], y=df3['Acute_cases'])

# %%
plt.figure(figsize=(12,8))
sns.jointplot(x='Year_end', y='Acute_cases', data=df4, kind='reg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-263c1667fb14> in <module>
#       1 plt.figure(figsize=(12,8))
# ----> 2 sns.jointplot(x='Year_end', y='Acute_cases', data=df4, kind='reg')
#
# NameError: name 'df4' is not defined

# %%
df4 = pd.DataFrame(df_Sierra_Leone.groupby('Town').sum()['Acute_cases'])

df4.reset_index(inplace=True)

df4

# %%
plt.figure(figsize=(25,10))
sns.barplot(x=df4['Town'], y=df4['Acute_cases'], data=df4, palette="deep")

# %% [markdown]
# # Nigeria

# %%
df_Nigeria = df_Acute[df_Acute['Country']=='Nigeria']

# %%
df_Nigeria.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-97e07fcc54bc> in <module>
# ----> 1 df_Nigeria.head()
#
# NameError: name 'df_Nigeria' is not defined

# %%
df_Guinea = df_Acute[df_Acute['Country']=='Guinea']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-04f2e192793f> in <module>
# ----> 1 df_Guinea = df_Acute[df_Acute['Country']=='Guinea']
#
# NameError: name 'df_Acute' is not defined

# %%
df_Guinea.head()

# %%
df_Liberia  = df_Acute[df_Acute['Country']=='Liberia']

# %%
df_Liberia.head()

# %%
df_Ghana  = df_Acute[df_Acute['Country']=='Ghana']

# %%
df_Ghana

# %%
df_Mali  = df_Acute[df_Acute['Country']=='Mali']

# %%
df_Mali

# %%
df_Cote_dIvoire  = df_Acute[df_Acute['Country']=="Cote d'Ivoire"]

# %%
df_Cote_dIvoire

# %%
df_Benin  = df_Acute[df_Acute['Country']=="Benin"]

# %%
df_Benin

# %%
df_Burkina_Faso  = df_Acute[df_Acute['Country']=="Burkina Faso"]

# %%
df_Burkina_Faso

# %% [markdown]
# # Nigeria

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns
# %matplotlib inline


df = pd.read_csv("convertcsv.csv")

# %%
df_Acute = df[df['Acutedisease_or_seroprevalence']=='Acute']

# %%
df['Country'].unique()
# Out:
# array(['Nigeria', 'Liberia', "Cote d'Ivoire", 'Sierra Leone', 'Mali',
#        'Burkina Faso', 'Guinea', 'Ghana', 'Benin'], dtype=object)

# %%
array(['Nigeria', 'Liberia', "Cote d'Ivoire", 'Sierra Leone', 'Mali',
       'Burkina Faso', 'Guinea', 'Ghana', 'Benin'], dtype=object)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-828495b4f587> in <module>
# ----> 1 array(['Nigeria', 'Liberia', "Cote d'Ivoire", 'Sierra Leone', 'Mali',
#       2        'Burkina Faso', 'Guinea', 'Ghana', 'Benin'], dtype=object)
#
# NameError: name 'array' is not defined

# %%
df_seroprevalence = df[df['Acutedisease_or_seroprevalence']=='seroprevalence']

# %%
df['Acutedisease_or_seroprevalence']=='seroprevalence'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 302    False
# 303    False
# 304    False
# 305    False
# 306    False
# Name: Acutedisease_or_seroprevalence, Length: 307, dtype: bool

# %%
df_Nigeria = df_Acute[df_Acute['Country']=='Nigeria']

# %%
df_Nigeria.drop(['ID', 'Rodent_or_human', 'Acutedisease_or_seroprevalence'], axis=1, inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_Nigeria['Acute_cases'] = df_Nigeria['Acute_cases'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Acute_cases'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-aac94c21199d> in <module>
# ...

# %%
df_Nigeria.reset_index(inplace=True)

# %%
df_Nigeria.drop(['Number_acutecases'], axis=1, inplace=True)

# %%
df_Nigeria.drop('index', axis=1, inplace=True)

# %%
plt.figure(figsize=(20,8))
plt.ylabel('Count')
plt.xlabel('Administrated Region')
sns.set_style('white')
plt.title('Relation Between Administrated Regions in Nigeria and Number of Acutecases of Lassa Fever')
sns.countplot(x='Admin_region', data=df_Nigeria)

plt.savefig('nigbars2.png')

# %%
plt.figure(figsize=(12,8))
plt.ylabel('Year of end')
plt.xlabel('Year of Start')
sns.lineplot(x=df_Nigeria['Year_start'],
            y=df_Nigeria['Year_end'])
